# %% [markdown]
# # Árvore de decisão
#
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)
#
# ## Calculo: ![image-3.png](attachment:image-3.png)
#
# ## Calculando a entropia para a base inteira ![image-4.png](attachment:image-4.png)
#
#
# ## Calculando o ganho de informação de cada atributo, o que tiver maior ganho é o mais significativo para estar na raiz da arvore de decisão
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# ## Portanto, a renda é o atributo mais importante, para continuar construindo a árvore é preciso aplicar os cálculos novamente  utilizando a renda como parâmetro. A dívida pode ser retirada da árvore já que possui pouco ganho de informação
# ![image-9.png](attachment:image-9.png)
#
# ----------------------------------------------------------------------
# ## Diferente forma de visualizar
#
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#  ## Vantagens:
#  * Fácil interpretação
#  * Rápida classificação
#  * Não tem que normalizar ou padronizar
#
#  ## Desvantagens
#  * Gerar árvores muito complexas
#  * Alteração nos dados altera a árvore
